# %%
import pandas as pd
import json
from transformers import pipeline
import numpy as np

# %%
with open('calendar.json','r') as f:
      data = json.load(f)

# %%
data
# Out:
# [{'date': 'Sun',
#   'time': '11:30pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Barkin Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '5:20am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Bank Lending y/y',
#   'actual': '2.4%',
#   'forecast': '2.8%',
#   'previous': '2.8%'},
#  {'date': 'Mon',
#   'time': None,
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Current Account',
#   'actual': '2.72T',
#   'forecast': '2.42T',
#   'previous': '2.91T'},
#  {'date': 'Mon',
#   'time': '10:30am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Economy Watchers Sentiment',
#   'actual': '42.6',
#   'forecast': '44.7',
#   'previous': '45.1'},
#  {'date': 'Mon',
#   'time': '1:30pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Lombardelli Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': 'All Day',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Eurogroup Meetings',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '4:00pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Greene Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '6:20pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Mann Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '7:00pm',
#   'currency': 'USD',
#   'impact': 'Medium',
#   'event': 'President Trump Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '7:15pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Cleveland Fed Inflation Expectations',
#   'actual': '3.9%',
#   'forecast': None,
#   'previous': '3.2%'},
#  {'date': 'Mon',
#   'time': '7:55pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Kugler Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '9:30pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Taylor Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Mon',
#   'time': '11:30pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Federal Budget Balance',
#   'actual': '258.4B',
#   'forecast': '256.4B',
#   'previous': '-160.5B'},
#  {'date': 'Mon',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Loan Officer Survey',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Tue',
#   'time': '4:31am',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'BRC Retail Sales Monitor y/y',
#   'actual': '6.8%',
#   'forecast': '2.4%',
#   'previous': '0.9%'},
#  {'date': 'Tue',
#   'time': '5:20am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'BOJ Summary of Opinions',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'M2 Money Stock y/y',
#   'actual': '0.5%',
#   'forecast': '0.6%',
#   'previous': '0.8%'},
#  {'date': 'Tue',
#   'time': '5:56am',
#   'currency': 'AUD',
#   'impact': 'Low',
#   'event': 'Westpac Consumer Sentiment',
#   'actual': '2.2%',
#   'forecast': None,
#   'previous': '-6.0%'},
#  {'date': 'Tue',
#   'time': '7:00am',
#   'currency': 'AUD',
#   'impact': 'Low',
#   'event': 'NAB Business Confidence',
#   'actual': '-1',
#   'forecast': None,
#   'previous': '-3'},
#  {'date': 'Tue',
#   'time': '9:05am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': '30-y Bond Auction',
#   'actual': '2.94|3.1',
#   'forecast': None,
#   'previous': '2.41|3.0'},
#  {'date': 'Tue',
#   'time': '11:30am',
#   'currency': 'GBP',
#   'impact': 'High',
#   'event': 'Claimant Count Change',
#   'actual': '5.2K',
#   'forecast': '22.3K',
#   'previous': '-16.9K'},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Medium',
#   'event': 'Average Earnings Index 3m/y',
#   'actual': '5.5%',
#   'forecast': '5.2%',
#   'previous': '5.7%'},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Unemployment Rate',
#   'actual': '4.5%',
#   'forecast': '4.5%',
#   'previous': '4.4%'},
#  {'date': 'Tue',
#   'time': 'All Day',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'ECOFIN Meetings',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Tue',
#   'time': '2:15pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Pill Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Tue',
#   'time': '2:30pm',
#   'currency': 'EUR',
#   'impact': 'Medium',
#   'event': 'German ZEW Economic Sentiment',
#   'actual': '25.2',
#   'forecast': '10.7',
#   'previous': '-14.0'},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'ZEW Economic Sentiment',
#   'actual': '11.6',
#   'forecast': '-3.5',
#   'previous': '-18.5'},
#  {'date': 'Tue',
#   'time': '3:30pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'NFIB Small Business Index',
#   'actual': '95.8',
#   'forecast': '94.9',
#   'previous': '97.4'},
#  {'date': 'Tue',
#   'time': '6:00pm',
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Core CPI m/m',
#   'actual': '0.2%',
#   'forecast': '0.3%',
#   'previous': '0.1%'},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'CPI m/m',
#   'actual': '0.2%',
#   'forecast': '0.3%',
#   'previous': '-0.1%'},
#  {'date': 'Tue',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'CPI y/y',
#   'actual': '2.3%',
#   'forecast': '2.4%',
#   'previous': '2.4%'},
#  {'date': 'Tue',
#   'time': '7:00pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'CB Leading Index m/m',
#   'actual': '-0.4%',
#   'forecast': None,
#   'previous': '-0.1%'},
#  {'date': 'Tue',
#   'time': '8:30pm',
#   'currency': 'GBP',
#   'impact': 'High',
#   'event': 'BOE Gov Bailey Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Tue',
#   'time': '9:04pm',
#   'currency': 'USD',
#   'impact': 'Medium',
#   'event': 'President Trump Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': '2:00am',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'API Weekly Statistical Bulletin',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': '4:15am',
#   'currency': 'NZD',
#   'impact': 'Low',
#   'event': 'Visitor Arrivals m/m',
#   'actual': None,
#   'forecast': None,
#   'previous': '-3.7%'},
#  {'date': 'Wed',
#   'time': '5:20am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'PPI y/y',
#   'actual': None,
#   'forecast': '4.0%',
#   'previous': '4.2%'},
#  {'date': 'Wed',
#   'time': '7:00am',
#   'currency': 'AUD',
#   'impact': 'High',
#   'event': 'Wage Price Index q/q',
#   'actual': None,
#   'forecast': '0.8%',
#   'previous': '0.7%'},
#  {'date': 'Wed',
#   'time': '11:30am',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'German Final CPI m/m',
#   'actual': None,
#   'forecast': '0.4%',
#   'previous': '0.4%'},
#  {'date': 'Wed',
#   'time': '12:45pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Breeden Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': 'Tentative',
#   'currency': 'CNY',
#   'impact': 'Medium',
#   'event': 'New Loans',
#   'actual': None,
#   'forecast': '710B',
#   'previous': '3640B'},
#  {'date': 'Wed',
#   'time': 'Tentative',
#   'currency': 'CNY',
#   'impact': 'Low',
#   'event': 'M2 Money Supply y/y',
#   'actual': None,
#   'forecast': '7.2%',
#   'previous': '7.0%'},
#  {'date': 'Wed',
#   'time': '1:45pm',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'German Buba President Nagel Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': '2:45pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Waller Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': 'Tentative',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': '10-y Bond Auction',
#   'actual': None,
#   'forecast': None,
#   'previous': '4.64|2.9'},
#  {'date': 'Wed',
#   'time': 'Tentative',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'German 30-y Bond Auction',
#   'actual': None,
#   'forecast': None,
#   'previous': '2.90|1.7'},
#  {'date': 'Wed',
#   'time': '6:00pm',
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Building Permits m/m',
#   'actual': None,
#   'forecast': '-0.7%',
#   'previous': '2.9%'},
#  {'date': 'Wed',
#   'time': '6:40pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Jefferson Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Wed',
#   'time': '8:00pm',
#   'currency': 'AUD',
#   'impact': 'Low',
#   'event': 'CB Leading Index m/m',
#   'actual': None,
#   'forecast': None,
#   'previous': '0.0%'},
#  {'date': 'Wed',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Crude Oil Inventories',
#   'actual': None,
#   'forecast': '-2.0M',
#   'previous': '-2.0M'},
#  {'date': 'Thu',
#   'time': 'Tentative',
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Annual Budget Release',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Thu',
#   'time': '3:10am',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Daly Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Thu',
#   'time': '4:15am',
#   'currency': 'NZD',
#   'impact': 'Low',
#   'event': 'FPI m/m',
#   'actual': None,
#   'forecast': None,
#   'previous': '0.5%'},
#  {'date': 'Thu',
#   'time': '6:30am',
#   'currency': 'AUD',
#   'impact': 'Low',
#   'event': 'MI Inflation Expectations',
#   'actual': None,
#   'forecast': None,
#   'previous': '4.2%'},
#  {'date': 'Thu',
#   'time': '7:00am',
#   'currency': 'AUD',
#   'impact': 'High',
#   'event': 'Employment Change',
#   'actual': None,
#   'forecast': '20.9K',
#   'previous': '32.2K'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'AUD',
#   'impact': 'High',
#   'event': 'Unemployment Rate',
#   'actual': None,
#   'forecast': '4.1%',
#   'previous': '4.1%'},
#  {'date': 'Thu',
#   'time': '11:30am',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'German WPI m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '-0.2%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'High',
#   'event': 'GDP m/m',
#   'actual': None,
#   'forecast': '0.0%',
#   'previous': '0.5%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Medium',
#   'event': 'Prelim GDP q/q',
#   'actual': None,
#   'forecast': '0.6%',
#   'previous': '0.1%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Construction Output m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '0.4%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Goods Trade Balance',
#   'actual': None,
#   'forecast': '-19.7B',
#   'previous': '-20.8B'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Index of Services 3m/3m',
#   'actual': None,
#   'forecast': '0.7%',
#   'previous': '0.6%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Industrial Production m/m',
#   'actual': None,
#   'forecast': '-0.6%',
#   'previous': '1.5%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Manufacturing Production m/m',
#   'actual': None,
#   'forecast': '-0.8%',
#   'previous': '2.2%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'Prelim Business Investment q/q',
#   'actual': None,
#   'forecast': '0.4%',
#   'previous': '-1.9%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Prelim Machine Tool Orders y/y',
#   'actual': None,
#   'forecast': None,
#   'previous': '11.4%'},
#  {'date': 'Thu',
#   'time': '12:00pm',
#   'currency': 'CHF',
#   'impact': 'Low',
#   'event': 'PPI m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '0.1%'},
#  {'date': 'Thu',
#   'time': '12:15pm',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'French Final CPI m/m',
#   'actual': None,
#   'forecast': '0.5%',
#   'previous': '0.5%'},
#  {'date': 'Thu',
#   'time': '2:30pm',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Flash Employment Change q/q',
#   'actual': None,
#   'forecast': '0.1%',
#   'previous': '0.1%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Flash GDP q/q',
#   'actual': None,
#   'forecast': '0.4%',
#   'previous': '0.4%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Industrial Production m/m',
#   'actual': None,
#   'forecast': '1.7%',
#   'previous': '1.1%'},
#  {'date': 'Thu',
#   'time': '5:45pm',
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Housing Starts',
#   'actual': None,
#   'forecast': '234K',
#   'previous': '214K'},
#  {'date': 'Thu',
#   'time': '6:00pm',
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Manufacturing Sales m/m',
#   'actual': None,
#   'forecast': '-1.8%',
#   'previous': '0.2%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Wholesale Sales m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '0.3%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Core PPI m/m',
#   'actual': None,
#   'forecast': '0.3%',
#   'previous': '-0.1%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Core Retail Sales m/m',
#   'actual': None,
#   'forecast': '0.3%',
#   'previous': '0.5%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'PPI m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '-0.4%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Retail Sales m/m',
#   'actual': None,
#   'forecast': '0.0%',
#   'previous': '1.4%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Unemployment Claims',
#   'actual': None,
#   'forecast': '229K',
#   'previous': '228K'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Medium',
#   'event': 'Empire State Manufacturing Index',
#   'actual': None,
#   'forecast': '-7.9',
#   'previous': '-8.1'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Medium',
#   'event': 'Philly Fed Manufacturing Index',
#   'actual': None,
#   'forecast': '-9.9',
#   'previous': '-26.4'},
#  {'date': 'Thu',
#   'time': '6:10pm',
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Fed Chair Powell Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Thu',
#   'time': '6:45pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Capacity Utilization Rate',
#   'actual': None,
#   'forecast': '77.9%',
#   'previous': '77.8%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Industrial Production m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '-0.3%'},
#  {'date': 'Thu',
#   'time': '7:30pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Dhingra Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Business Inventories m/m',
#   'actual': None,
#   'forecast': '0.2%',
#   'previous': '0.2%'},
#  {'date': 'Thu',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'NAHB Housing Market Index',
#   'actual': None,
#   'forecast': '40',
#   'previous': '40'},
#  {'date': 'Thu',
#   'time': 'Tentative',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Mortgage Delinquencies',
#   'actual': None,
#   'forecast': None,
#   'previous': '3.98%'},
#  {'date': 'Thu',
#   'time': '8:00pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Natural Gas Storage',
#   'actual': None,
#   'forecast': None,
#   'previous': '104B'},
#  {'date': 'Thu',
#   'time': '11:35pm',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Barr Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Fri',
#   'time': '4:00am',
#   'currency': 'NZD',
#   'impact': 'Low',
#   'event': 'BusinessNZ Manufacturing Index',
#   'actual': None,
#   'forecast': None,
#   'previous': '53.2'},
#  {'date': 'Fri',
#   'time': '5:20am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Prelim GDP Price Index y/y',
#   'actual': None,
#   'forecast': '3.2%',
#   'previous': '2.9%'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Prelim GDP q/q',
#   'actual': None,
#   'forecast': '-0.1%',
#   'previous': '0.7%'},
#  {'date': 'Fri',
#   'time': '8:30am',
#   'currency': 'NZD',
#   'impact': 'Medium',
#   'event': 'Inflation Expectations q/q',
#   'actual': None,
#   'forecast': None,
#   'previous': '2.06%'},
#  {'date': 'Fri',
#   'time': '10:00am',
#   'currency': 'JPY',
#   'impact': 'Low',
#   'event': 'Revised Industrial Production m/m',
#   'actual': None,
#   'forecast': '-1.1%',
#   'previous': '-1.1%'},
#  {'date': 'Fri',
#   'time': '2:30pm',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Italian Trade Balance',
#   'actual': None,
#   'forecast': '5.15B',
#   'previous': '4.47B'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'Trade Balance',
#   'actual': None,
#   'forecast': '17.5B',
#   'previous': '21.0B'},
#  {'date': 'Fri',
#   'time': 'Tentative',
#   'currency': 'EUR',
#   'impact': 'Low',
#   'event': 'EU Economic Forecasts',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Fri',
#   'time': '4:30pm',
#   'currency': 'CHF',
#   'impact': 'Medium',
#   'event': 'SNB Chairman Schlegel Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Fri',
#   'time': '6:00pm',
#   'currency': 'CAD',
#   'impact': 'Low',
#   'event': 'Foreign Securities Purchases',
#   'actual': None,
#   'forecast': None,
#   'previous': '-6.46B'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Building Permits',
#   'actual': None,
#   'forecast': '1.45M',
#   'previous': '1.48M'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Housing Starts',
#   'actual': None,
#   'forecast': '1.37M',
#   'previous': '1.32M'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'Import Prices m/m',
#   'actual': None,
#   'forecast': '-0.4%',
#   'previous': '-0.1%'},
#  {'date': 'Fri',
#   'time': 'Tentative',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Barkin Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Fri',
#   'time': '7:30pm',
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Prelim UoM Consumer Sentiment',
#   'actual': None,
#   'forecast': '53.1',
#   'previous': '52.2'},
#  {'date': 'Fri',
#   'time': None,
#   'currency': 'USD',
#   'impact': 'High',
#   'event': 'Prelim UoM Inflation Expectations',
#   'actual': None,
#   'forecast': None,
#   'previous': '6.5%'},
#  {'date': 'Fri',
#   'time': '8:30pm',
#   'currency': 'GBP',
#   'impact': 'Low',
#   'event': 'MPC Member Lombardelli Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None},
#  {'date': 'Sat',
#   'time': '1:30am',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'TIC Long-Term Purchases',
#   'actual': None,
#   'forecast': '44.2B',
#   'previous': '112.0B'},
#  {'date': 'Sat',
#   'time': '7:10am',
#   'currency': 'USD',
#   'impact': 'Low',
#   'event': 'FOMC Member Daly Speaks',
#   'actual': None,
#   'forecast': None,
#   'previous': None}]

# %%
df = pd.DataFrame(data)

# %%
def clean_percent(val):
  try:
    return float(val.strip('%'))
  except:
    return None

# %%
df['actual_val'] = df['actual'].apply(clean_percent)
df['forecast_val'] = df['forecast'].apply(clean_percent)
df['previous_val'] = df['previous'].apply(clean_percent)

# %%
df
# Out:
#     date     time currency impact                              event actual  \
# 0    Sun  11:30pm      USD    Low          FOMC Member Barkin Speaks   None
# 1    Mon   5:20am      JPY    Low                   Bank Lending y/y   2.4%
# 2    Mon     None      JPY    Low                    Current Account  2.72T
# 3    Mon  10:30am      JPY    Low         Economy Watchers Sentiment   42.6
# 4    Mon   1:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# ..   ...      ...      ...    ...                                ...    ...
# 104  Fri   7:30pm      USD   High      Prelim UoM Consumer Sentiment   None
# 105  Fri     None      USD   High  Prelim UoM Inflation Expectations   None
# 106  Fri   8:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# 107  Sat   1:30am      USD    Low            TIC Long-Term Purchases   None
# 108  Sat   7:10am      USD    Low            FOMC Member Daly Speaks   None
#
#     forecast previous  actual_val  forecast_val  previous_val
# 0       None     None         NaN           NaN           NaN
# 1       2.8%     2.8%         2.4           2.8           2.8
# 2      2.42T    2.91T         NaN           NaN           NaN
# 3       44.7     45.1        42.6          44.7          45.1
# 4       None     None         NaN           NaN           NaN
# ..       ...      ...         ...           ...           ...
# 104     53.1     52.2         NaN          53.1          52.2
# 105     None     6.5%         NaN           NaN           6.5
# 106     None     None         NaN           NaN           NaN
# 107    44.2B   112.0B         NaN           NaN           NaN
# 108     None     None         NaN           NaN           NaN
#
# [109 rows x 11 columns]

# %%
for col in ['actual_val','forecast_val','previous_val']:
  mean_val = df[col].mean()
  df[col].fillna(mean_val,inplace=True)
# Out:
# <ipython-input-8-edc91e088ad3>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mean_val,inplace=True)

# %%
df
# Out:
#     date     time currency impact                              event actual  \
# 0    Sun  11:30pm      USD    Low          FOMC Member Barkin Speaks   None
# 1    Mon   5:20am      JPY    Low                   Bank Lending y/y   2.4%
# 2    Mon     None      JPY    Low                    Current Account  2.72T
# 3    Mon  10:30am      JPY    Low         Economy Watchers Sentiment   42.6
# 4    Mon   1:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# ..   ...      ...      ...    ...                                ...    ...
# 104  Fri   7:30pm      USD   High      Prelim UoM Consumer Sentiment   None
# 105  Fri     None      USD   High  Prelim UoM Inflation Expectations   None
# 106  Fri   8:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# 107  Sat   1:30am      USD    Low            TIC Long-Term Purchases   None
# 108  Sat   7:10am      USD    Low            FOMC Member Daly Speaks   None
#
#     forecast previous  actual_val  forecast_val  previous_val
# 0       None     None    12.64375      7.064583      5.961311
# 1       2.8%     2.8%     2.40000      2.800000      2.800000
# 2      2.42T    2.91T    12.64375      7.064583      5.961311
# 3       44.7     45.1    42.60000     44.700000     45.100000
# 4       None     None    12.64375      7.064583      5.961311
# ..       ...      ...         ...           ...           ...
# 104     53.1     52.2    12.64375     53.100000     52.200000
# 105     None     6.5%    12.64375      7.064583      6.500000
# 106     None     None    12.64375      7.064583      5.961311
# 107    44.2B   112.0B    12.64375      7.064583      5.961311
# 108     None     None    12.64375      7.064583      5.961311
#
# [109 rows x 11 columns]

# %%
def infer_impact(row):
  if pd.notnull(row['impact']):
    return row['impact']

  forecast = row['forecast_val']
  actual = row['actual_val']
  if forecast == 0:
    return 'Low'

  deviation = abs(actual - forecast) / forecast
  if deviation >0.05:
    return 'High'
  elif deviation > 0.02:
    return 'Medium'
  else:
    return 'Low'


df['impact']=df.apply(infer_impact, axis = 1)

# %%
df
# Out:
#     date     time currency impact                              event actual  \
# 0    Sun  11:30pm      USD    Low          FOMC Member Barkin Speaks   None
# 1    Mon   5:20am      JPY    Low                   Bank Lending y/y   2.4%
# 2    Mon     None      JPY    Low                    Current Account  2.72T
# 3    Mon  10:30am      JPY    Low         Economy Watchers Sentiment   42.6
# 4    Mon   1:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# ..   ...      ...      ...    ...                                ...    ...
# 104  Fri   7:30pm      USD   High      Prelim UoM Consumer Sentiment   None
# 105  Fri     None      USD   High  Prelim UoM Inflation Expectations   None
# 106  Fri   8:30pm      GBP    Low      MPC Member Lombardelli Speaks   None
# 107  Sat   1:30am      USD    Low            TIC Long-Term Purchases   None
# 108  Sat   7:10am      USD    Low            FOMC Member Daly Speaks   None
#
#     forecast previous  actual_val  forecast_val  previous_val
# 0       None     None    12.64375      7.064583      5.961311
# 1       2.8%     2.8%     2.40000      2.800000      2.800000
# 2      2.42T    2.91T    12.64375      7.064583      5.961311
# 3       44.7     45.1    42.60000     44.700000     45.100000
# 4       None     None    12.64375      7.064583      5.961311
# ..       ...      ...         ...           ...           ...
# 104     53.1     52.2    12.64375     53.100000     52.200000
# 105     None     6.5%    12.64375      7.064583      6.500000
# 106     None     None    12.64375      7.064583      5.961311
# 107    44.2B   112.0B    12.64375      7.064583      5.961311
# 108     None     None    12.64375      7.064583      5.961311
#
# [109 rows x 11 columns]

# %%
def rule_sentiment(row):
    event = row['event'].lower()
    actual = row['actual_val']
    forecast = row['forecast_val']

    # CPI: Rising inflation = Bearish
    if "cpi" in event:
        if actual > forecast:
            return 'bearish'
        elif actual < forecast:
            return 'bullish'
        else:
            return 'neutral'

    # NFP: Strong employment = Bullish
    elif "non-farm" in event or "nfp" in event:
        if actual > forecast:
            return 'bullish'
        elif actual < forecast:
            return 'bearish'
        else:
            return 'neutral'

    # FOMC / Rate events
    elif "fomc" in event or "interest rate" in event or "rate statement" in event:
        if "rate hike" in event:
            return 'bearish'
        elif "rate cut" in event:
            return 'bullish'
        else:
            return 'neutral'

    # Default for unknown event types
    else:
        return 'neutral'

df['rule_sentiment'] = df.apply(rule_sentiment, axis=1)

# %%
def build_input(row):
    return (
        f"EVENT: {row['event']} | "
        f"IMPACT (important): {row['impact']} | "
        f"FORECAST VALUE: {row['forecast_val']} | "
        f"PREVIOUS VALUE: {row['previous_val']} | "
        f"ACTUAL RESULT: {row['actual_val']}"
    )

# %%
df['finber_input'] = df.apply(build_input,axis=1)

# %%
df['finber_input']
# Out:
# 0      EVENT: FOMC Member Barkin Speaks | IMPACT (imp...
# 1      EVENT: Bank Lending y/y | IMPACT (important): ...
# 2      EVENT: Current Account | IMPACT (important): L...
# 3      EVENT: Economy Watchers Sentiment | IMPACT (im...
# 4      EVENT: MPC Member Lombardelli Speaks | IMPACT ...
#                              ...
# 104    EVENT: Prelim UoM Consumer Sentiment | IMPACT ...
# 105    EVENT: Prelim UoM Inflation Expectations | IMP...
# 106    EVENT: MPC Member Lombardelli Speaks | IMPACT ...
# 107    EVENT: TIC Long-Term Purchases | IMPACT (impor...
# 108    EVENT: FOMC Member Daly Speaks | IMPACT (impor...
# Name: finber_input, Length: 109, dtype: object

# %%
classifier = pipeline("sentiment-analysis", model="ProsusAI/finbert")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
df['nlp_sentiment'] = df['finber_input'].apply(lambda x: classifier(x)[0]['label'])
df['nlp_confidence'] = df['finber_input'].apply(lambda x: classifier(x)[0]['score'])

# %%
def combine_sentiment(row):
    rule = row['rule_sentiment']
    nlp = row['nlp_sentiment'].lower()
    impact = row['impact'].lower()

    impact_weight = {'low': 1, 'medium': 2, 'high': 3}
    weight = impact_weight.get(impact, 1)

    if rule == nlp:
        return rule
    if weight >= 2:
        return rule
    return {
        'positive': 'bullish',
        'negative': 'bearish',
        'neutral': 'neutral'
    }.get(nlp, 'neutral')

df['market_sentiment'] = df.apply(combine_sentiment, axis=1)

# %%
print(df[['event', 'actual', 'forecast', 'impact', 'rule_sentiment', 'nlp_sentiment', 'market_sentiment']])
# Out:
#                                  event actual forecast impact rule_sentiment  \
# 0            FOMC Member Barkin Speaks   None     None    Low        neutral
# 1                     Bank Lending y/y   2.4%     2.8%    Low        neutral
# 2                      Current Account  2.72T    2.42T    Low        neutral
# 3           Economy Watchers Sentiment   42.6     44.7    Low        neutral
# 4        MPC Member Lombardelli Speaks   None     None    Low        neutral
# ..                                 ...    ...      ...    ...            ...
# 104      Prelim UoM Consumer Sentiment   None     53.1   High        neutral
# 105  Prelim UoM Inflation Expectations   None     None   High        neutral
# 106      MPC Member Lombardelli Speaks   None     None    Low        neutral
# 107            TIC Long-Term Purchases   None    44.2B    Low        neutral
# 108            FOMC Member Daly Speaks   None     None    Low        neutral
#
#     nlp_sentiment market_sentiment
# 0        negative          bearish
# 1        negative          bearish
# 2        negative          bearish
# 3        negative          bearish
# 4        negative          bearish
# ..            ...              ...
# 104       neutral          neutral
# 105       neutral          neutral
# 106      negative          bearish
# 107      negative          bearish
# 108      negative          bearish
#
# [109 rows x 7 columns]

# %%
df.to_csv('calender.csv')

# %%
import pickle

# %%
with open('combine_sentiment.pkl','wb') as file:
  pickle.dump(combine_sentiment,file)
